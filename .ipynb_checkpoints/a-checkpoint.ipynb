# %%
import tensorflow as tf
import os
import cv2
import imghdr
from matplotlib import pyplot as plt
import numpy as np

# %%
data_dir='Dataset'

# %%
data= tf.keras.utils.image_dataset_from_directory('Dataset')
data= data.map(lambda x,y:(x/255,y))
# Out:
# Found 396 files belonging to 4 classes.

# %%
data_iterator
# Out:
# NumpyIterator(iterator=<tensorflow.python.data.ops.iterator_ops.OwnedIterator object at 0x000001E280D8BBB0>)

# %%
batch=data_iterator.next()

#0-bus, 1-car, 2-motorcycle, 3-truck

# %%
fig, ax =plt.subplots(ncols=10, figsize=(20,20))
for idx, img in enumerate(batch[0][:10]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(batch[1][idx])

# %%
train_size=int(len(data)*.7)+1
val_size=int(len(data)*.2)+1
test_size=int(len(data)*.1)

# %%
train= data.take(train_size)
val=data.skip(train_size).take(val_size)
test=data.skip(train_size+val_size).take(test_size)

# %%
len(train)
# Out:
# 10

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model=Sequential()

# %%
model.add(Conv2D(16,(3,3),1,activation='relu',input_shape=(256,256,3)))
model.add(MaxPooling2D())

model.add(Conv2D(32, (3,3),1,activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16, (3,3),1,activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(4,activation='softmax'))

# %%
model.compile('adam', loss=tf.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_27 (Conv2D)                   │ (None, 254, 254, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_21 (MaxPooling2D)      │ (None, 127, 127, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_28 (Conv2D)                   │ (None, 125, 125, 32)        │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_22 (MaxPooling2D)      │ (None, 62, 62, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_29 (Conv2D)                   │ (None, 60, 60, 16)          │           4,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_23 (MaxPooling2D)      │ (None, 30, 30, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_7 (Flatten)                  │ (None, 14400)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 256)                 │       3,686,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 4)                   │           1,028 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,697,396 (14.10 MB)
#  Trainable params: 3,697,396 (14.10 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
logdir='logs'

# %%
tensorboard_callback=tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.2577 - loss: 1.3952 - val_accuracy: 0.4474 - val_loss: 1.2780
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 919ms/step - accuracy: 0.4927 - loss: 1.1826 - val_accuracy: 0.7237 - val_loss: 0.8228
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 946ms/step - accuracy: 0.7351 - loss: 0.7705 - val_accuracy: 0.8289 - val_loss: 0.4406
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 938ms/step - accuracy: 0.8806 - loss: 0.3652 - val_accuracy: 0.9474 - val_loss: 0.2073
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 954ms/step - accuracy: 0.9715 - loss: 0.1880 - val_accuracy: 1.0000 - val_loss: 0.0512
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 993ms/step - accuracy: 0.9867 - loss: 0.0678 - val_accuracy: 0.9868 - val_loss: 0.0416
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 991ms/step - accuracy: 0.9991 - loss: 0.0329 - val_accuracy: 0.9868 - val_loss: 0.0311
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 999ms/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 981ms/step - accuracy: 0.9984 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 988ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 0.0081
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 981ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 984ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 7.6958e-04
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 5.4458e-04 - val_accuracy: 1.0000 - val_loss: 4.3392e-04
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 3.7428e-04 - val_accuracy: 1.0000 - val_loss: 4.5462e-04
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 3.5004e-04 - val_accuracy: 1.0000 - val_loss: 3.0427e-04
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 964ms/step - accuracy: 1.0000 - loss: 2.3311e-04 - val_accuracy: 1.0000 - val_loss: 2.1108e-04
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 2.5626e-04 - val_accuracy: 1.0000 - val_loss: 2.0262e-04
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 984ms/step - accuracy: 1.0000 - loss: 1.8840e-04 - val_accuracy: 1.0000 - val_loss: 2.3250e-04
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 922ms/step - accuracy: 1.0000 - loss: 1.6768e-04 - val_accuracy: 1.0000 - val_loss: 2.4325e-04
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 1.6591e-04 - val_accuracy: 1.0000 - val_loss: 1.6395e-04

# %%
fig=plt.figure()
plt.plot(hist.history['accuracy'],color='teal',label='accuracy')
plt.plot(hist.history['val_accuracy'],color='orange',label='val_accuracy')

fig.suptitle('Accuracy',fontsize=20)
plt.show()

# %%
fig=plt.figure()
plt.plot(hist.history['loss'],color='teal',label='loss')
plt.plot(hist.history['val_loss'],color='orange',label='val_loss')

fig.suptitle('Loss',fontsize=20)
plt.show()

# %%
from tensorflow.keras.metrics import Precision,Recall,BinaryAccuracy

# %%
pre=Precision()
re=Recall()
acc=BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator():
    x,y=batch 
    yhat=model.predict(x)
    acc.update_state(y,yhat)

# %%
def get_class(prediction):
    classes = ["Bus", "Car", "Motorcycle", "Truck"]
    return classes[np.argmax(prediction)]

# %%
img = cv2.imread('test.png')
resize = tf.image.resize(img, (256, 256))
np.expand_dims(resize, 0)
prediction = model.predict(np.expand_dims(resize / 255, 0))

object_class = get_class(prediction[0])
confidence = np.max(prediction)

print(f"Predicted Object: {object_class}, Confidence: {confidence}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Predicted Object: Car, Confidence: 0.9906557202339172
